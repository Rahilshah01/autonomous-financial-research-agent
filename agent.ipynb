# %%
import os
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process, LLM
from textwrap import dedent

load_dotenv()

# 1. Setup Environment and LLM
gemini_flash = LLM(
    model="gemini/gemini-2.5-flash-lite",
    api_key=os.getenv("GEMINI_API_KEY")
)

# 2. Define Specialized Agents
researcher = Agent(
    role='Senior Financial Researcher',
    goal='Uncover deep insights into {company} and its 2025 market outlook.',
    backstory=dedent("""You are a world-class financial analyst. You specialize in 
    identifying emerging market trends for {company}."""),
    llm=gemini_flash,
    verbose=True
)

writer = Agent(
    role='Technical Financial Writer',
    goal='Synthesize research findings into a clear, investor-ready report.',
    backstory=dedent("""You are a seasoned business journalist. You transform raw 
    financial data into compelling, structured narratives for executive stakeholders."""),
    llm=gemini_flash,
    verbose=True
)

# 3. Define the Workflow Tasks
research_task = Task(
    description=dedent("""Research current financial trends for {company}. 
    Identify three key growth drivers and three potential risks."""),
    expected_output="A structured report for {company} including growth drivers and risks.",
    agent=researcher
)

writing_task = Task(
    description=dedent("""Using the research findings, write a high-level 3-paragraph 
    investment summary. Focus on the core recommendation (Buy/Hold/Sell)."""),
    expected_output="A polished 3-paragraph financial report in Markdown format.",
    agent=writer
)

# 4. Form and Kickoff the Crew
fin_crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, writing_task],
    process=Process.sequential, # Researcher must finish before Writer starts
    verbose=True
)

if __name__ == "__main__":
    print("\n--- Starting Autonomous Financial Research ---")
    result = fin_crew.kickoff(inputs={'company': 'NVIDIA'})
    print("\n--- FINAL FINANCIAL REPORT ---\n")
    print(result)
# Out:
# --- Starting Autonomous Financial Research ---
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9ede48b7-843c-48d2-af8f-e1cf1480fedc                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Financial Researcher                                                                             │
# │                                                                                                                 │
# │  Task: Research current financial trends for NVIDIA.                                                            │
# │      Identify three key growth drivers and three potential risks.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Financial Researcher                                                                             │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **NVIDIA: 2025 Market Outlook - Growth Drivers and Risks**                                                     │
# │                                                                                                                 │
# │  NVIDIA stands at the forefront of several transformative technological shifts, positioning it for continued    │
# │  expansion. However, the company is not without its challenges. This report outlines three key growth drivers   │
# │  and three significant risks that will shape NVIDIA's market outlook heading into 2025.                         │
# │                                                                                                                 │
# │  **Key Growth Drivers:**                                                                                        │
# │                                                                                                                 │
# │  1.  **Dominance in the AI and Accelerated Computing Market:**                                                  │
# │      *   **Description:** The relentless advancement and widespread adoption of Artificial Intelligence (AI),   │
# │  including machine learning, deep learning, and particularly large language models (LLMs), are creating an      │
# │  unprecedented demand for high-performance computing. NVIDIA's Graphics Processing Units (GPUs), especially     │
# │  its cutting-edge Hopper (H100) and the upcoming Blackwell architectures, are the de facto standard for         │
# │  training and inferencing complex AI models.                                                                    │
# │      *   **Impact:** Data center operators, cloud service providers (hyperscalers), enterprises, and research   │
# │  institutions are heavily investing in NVIDIA's hardware to power their AI initiatives. This demand is not      │
# │  just for raw processing power but also for NVIDIA's integrated software ecosystem (e.g., CUDA, cuDNN) that     │
# │  optimizes AI development and deployment, creating a strong ecosystem lock-in. The sheer scale of data being    │
# │  generated globally necessitates increasingly powerful and efficient processing capabilities, a domain where    │
# │  NVIDIA excels.                                                                                                 │
# │      *   **Outlook:** Projections indicate continued exponential growth in AI workloads, with NVIDIA's GPU      │
# │  shipments and revenue from its Data Center segment expected to remain robust. The ongoing development of more  │
# │  sophisticated AI models and applications will further fuel this demand.                                        │
# │                                                                                                                 │
# │  2.  **Expansion in the Automotive Sector (NVIDIA DRIVE):**                                                     │
# │      *   **Description:** The automotive industry is undergoing a profound transformation, with a rapid shift   │
# │  towards electrification, advanced driver-assistance systems (ADAS), and fully autonomous driving. NVIDIA's     │
# │  DRIVE platform offers a comprehensive suite of hardware (SoCs, GPUs) and software solutions specifically       │
# │  designed to handle the complex computational needs of modern vehicles, from infotainment and digital cockpits  │
# │  to sensor fusion and AI-driven decision-making for autonomous navigation.                                      │
# │      *   **Impact:** Major global automakers are increasingly partnering with NVIDIA to integrate its           │
# │  technology into their vehicle platforms. The demand for enhanced safety features, in-car intelligent           │
# │  experiences, and the long-term pursuit of Level 4 and Level 5 autonomous driving create a substantial and      │
# │  growing market for NVIDIA's specialized automotive processors and software.                                    │
# │      *   **Outlook:** As regulatory frameworks for autonomous driving mature and consumer acceptance grows,     │
# │  the automotive segment is poised to become a significant revenue contributor for NVIDIA. The company's early   │
# │  investment and strong relationships with key players position it favorably to capture a large share of this    │
# │  evolving market.                                                                                               │
# │                                                                                                                 │
# │  3.  **Innovation and Demand in the Gaming and Entertainment Industry:**                                        │
# │      *   **Description:** The gaming sector remains a cornerstone of NVIDIA's business, driven by the constant  │
# │  pursuit of more immersive and realistic visual experiences. NVIDIA's GeForce RTX graphics cards, featuring     │
# │  advanced technologies like real-time ray tracing and AI-powered DLSS (Deep Learning Super Sampling), continue  │
# │  to set the standard for high-end gaming performance.                                                           │
# │      *   **Impact:** The increasing popularity of esports, the growing complexity of AAA game titles, and the   │
# │  burgeoning interest in virtual and augmented reality (VR/AR) experiences fuel sustained demand for NVIDIA's    │
# │  consumer GPUs. Furthermore, the growth of cloud gaming services and the development of the metaverse concept   │
# │  represent new avenues for NVIDIA's technology to reach a broader audience and drive adoption in new forms of   │
# │  entertainment and social interaction.                                                                          │
# │      *   **Outlook:** Despite the cyclical nature of PC hardware, NVIDIA's commitment to technological          │
# │  leadership in graphics rendering and AI-enhanced gaming features ensures its relevance and continued demand    │
# │  from both professional gamers and a growing casual gaming audience seeking premium experiences.                │
# │                                                                                                                 │
# │  **Potential Risks:**                                                                                           │
# │                                                                                                                 │
# │  1.  **Intensifying Competition in AI and Data Center Chips:**                                                  │
# │      *   **Description:** While NVIDIA currently holds a near-monopoly in high-end AI accelerators,             │
# │  competition is rapidly heating up. Major cloud providers (e.g., Google with TPUs, Amazon with Inferent chips,  │
# │  Microsoft) are investing heavily in developing their own custom AI silicon designed for their specific         │
# │  workloads, potentially reducing their reliance on NVIDIA. Other semiconductor companies (e.g., AMD with its    │
# │  Instinct line, Intel) are also aggressively developing and marketing competitive AI solutions. Specialized AI  │
# │  chip startups are further fragmenting the market.                                                              │
# │      *   **Impact:** Increased competition could lead to pricing pressure on NVIDIA's GPUs, potentially         │
# │  impacting its industry-leading profit margins. If competitors achieve comparable or superior performance for   │
# │  certain AI tasks at a lower cost, NVIDIA could see a gradual erosion of its market share, particularly among   │
# │  cost-sensitive hyperscalers or enterprises.                                                                    │
# │      *   **Outlook:** NVIDIA's challenge will be to maintain its technological lead, expand its software        │
# │  ecosystem advantage, and demonstrate a compelling total cost of ownership (TCO) to fend off these growing      │
# │  competitive threats.                                                                                           │
# │                                                                                                                 │
# │  2.  **Supply Chain Vulnerabilities and Geopolitical Risks:**                                                   │
# │      *   **Description:** NVIDIA's reliance on advanced semiconductor foundries, primarily Taiwan               │
# │  Semiconductor Manufacturing Company (TSMC), for the fabrication of its most sophisticated chips makes it       │
# │  susceptible to disruptions in the global supply chain. Geopolitical tensions, particularly concerning          │
# │  Taiwan's status, and broader trade disputes can lead to manufacturing delays, increased costs, or even direct  │
# │  export restrictions on critical components.                                                                    │
# │      *   **Impact:** Any significant disruption in the foundry's operations or a tightening of international    │
# │  trade policies could severely impact NVIDIA's production capacity and its ability to meet global demand. This  │
# │  could lead to product shortages, extended lead times, and a negative impact on revenue and market confidence.  │
# │      *   **Outlook:** NVIDIA is actively working to diversify its supply chain and mitigate these risks, but    │
# │  the concentration of advanced manufacturing capabilities remains a significant vulnerability that could be     │
# │  exacerbated by geopolitical instability.                                                                       │
# │                                                                                                                 │
# │  3.  **Cyclicality of the Semiconductor Industry and Macroeconomic Downturns:**                                 │
# │      *   **Description:** The semiconductor industry is inherently cyclical, characterized by periods of high   │
# │  demand and rapid growth followed by potential slowdowns or corrections. While the current AI boom is           │
# │  exceptionally strong, a broader global economic recession or a significant slowdown in capital expenditure by  │
# │  major technology companies could dampen demand for high-end computing hardware.                                │
# │      *   **Impact:** A macroeconomic downturn could lead to reduced corporate spending, including on AI         │
# │  infrastructure and new gaming hardware. Hyperscalers might moderate their aggressive build-out plans, and      │
# │  consumers might cut back on discretionary spending for high-performance PCs and gaming consoles. This could    │
# │  result in slower revenue growth or even a decline in sales for NVIDIA's key segments.                          │
# │      *   **Outlook:** While AI remains a powerful secular trend, the pace of its adoption is still subject to   │
# │  economic realities. NVIDIA's premium pricing strategy for its flagship products could make them more           │
# │  vulnerable during periods of economic belt-tightening, prompting customers to seek more economical             │
# │  alternatives or postpone upgrades.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 23a803c3-bca6-470c-8973-80ba7fd7aa30                                                                     │
# │  Agent: Senior Financial Researcher                                                                             │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Financial Writer                                                                              │
# │                                                                                                                 │
# │  Task: Using the research findings, write a high-level 3-paragraph                                              │
# │      investment summary. Focus on the core recommendation (Buy/Hold/Sell).                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Financial Writer                                                                              │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The following is a high-level investment summary for NVIDIA, focusing on the core recommendation.              │
# │                                                                                                                 │
# │  **NVIDIA: Strategic Outlook and Investment Recommendation for 2025**                                           │
# │                                                                                                                 │
# │  NVIDIA is positioned for continued strong performance heading into 2025, driven by its entrenched leadership   │
# │  in the rapidly expanding AI and accelerated computing market. The company's high-performance GPUs and          │
# │  integrated software ecosystem are essential for the training and deployment of sophisticated AI models,        │
# │  creating significant customer lock-in. Furthermore, NVIDIA's strategic expansion into the automotive sector    │
# │  with its DRIVE platform, coupled with persistent innovation in the gaming and entertainment industries,        │
# │  presents substantial additional growth avenues. These diverse demand drivers, fueled by ongoing technological  │
# │  advancements and increasing adoption across critical industries, provide a robust foundation for sustained     │
# │  revenue growth and market dominance.                                                                           │
# │                                                                                                                 │
# │  Despite the compelling growth narrative, investors must acknowledge key risks that could impact NVIDIA's       │
# │  trajectory. Intensifying competition in the AI accelerator space from both major cloud providers developing    │
# │  in-house silicon and emerging semiconductor players poses a threat to NVIDIA's premium margins and market      │
# │  share. Additionally, the company's reliance on a concentrated global supply chain, particularly for advanced   │
# │  chip fabrication, exposes it to geopolitical vulnerabilities and potential disruptions. Finally, the inherent  │
# │  cyclicality of the semiconductor industry and the broader macroeconomic environment introduce the risk of      │
# │  reduced capital expenditure and consumer spending, which could temper demand for NVIDIA's high-end products.   │
# │                                                                                                                 │
# │  Considering the powerful secular tailwinds in AI, the strategic positioning in the automotive sector, and      │
# │  ongoing innovation in gaming, NVIDIA's competitive advantages and market position remain exceptionally         │
# │  strong. While competitive pressures, supply chain risks, and macroeconomic headwinds are present, the          │
# │  company's ability to innovate and maintain its technological lead is expected to outweigh these challenges in  │
# │  the near to medium term. Therefore, our core recommendation for NVIDIA heading into 2025 is a **Buy**.         │
# │  Investors should, however, remain vigilant regarding competitive developments and geopolitical factors, which  │
# │  warrant ongoing monitoring.                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 4f2ed26d-4016-4ee6-81ec-6ca5acbb13f9                                                                     │
# │  Agent: Technical Financial Writer                                                                              │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── Tracing Preference Saved ──────────────────────────────────────────────╮
# │                                                                                                                      │
# │  Info: Tracing has been disabled.                                                                                    │
# │                                                                                                                      │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                                │
# │                                                                                                                      │
# │  To enable tracing later, do any one of these:                                                                       │
# │  • Set tracing=True in your Crew/Flow code                                                                           │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                       │
# │  • Run: crewai traces enable                                                                                         │
# │                                                                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 9ede48b7-843c-48d2-af8f-e1cf1480fedc                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: The following is a high-level investment summary for NVIDIA, focusing on the core                │
# │  recommendation.                                                                                                │
# │                                                                                                                 │
# │  **NVIDIA: Strategic Outlook and Investment Recommendation for 2025**                                           │
# │                                                                                                                 │
# │  NVIDIA is positioned for continued strong performance heading into 2025, driven by its entrenched leadership   │
# │  in the rapidly expanding AI and accelerated computing market. The company's high-performance GPUs and          │
# │  integrated software ecosystem are essential for the training and deployment of sophisticated AI models,        │
# │  creating significant customer lock-in. Furthermore, NVIDIA's strategic expansion into the automotive sector    │
# │  with its DRIVE platform, coupled with persistent innovation in the gaming and entertainment industries,        │
# │  presents substantial additional growth avenues. These diverse demand drivers, fueled by ongoing technological  │
# │  advancements and increasing adoption across critical industries, provide a robust foundation for sustained     │
# │  revenue growth and market dominance.                                                                           │
# │                                                                                                                 │
# │  Despite the compelling growth narrative, investors must acknowledge key risks that could impact NVIDIA's       │
# │  trajectory. Intensifying competition in the AI accelerator space from both major cloud providers developing    │
# │  in-house silicon and emerging semiconductor players poses a threat to NVIDIA's premium margins and market      │
# │  share. Additionally, the company's reliance on a concentrated global supply chain, particularly for advanced   │
# │  chip fabrication, exposes it to geopolitical vulnerabilities and potential disruptions. Finally, the inherent  │
# │  cyclicality of the semiconductor industry and the broader macroeconomic environment introduce the risk of      │
# │  reduced capital expenditure and consumer spending, which could temper demand for NVIDIA's high-end products.   │
# │                                                                                                                 │
# │  Considering the powerful secular tailwinds in AI, the strategic positioning in the automotive sector, and      │
# │  ongoing innovation in gaming, NVIDIA's competitive advantages and market position remain exceptionally         │
# │  strong. While competitive pressures, supply chain risks, and macroeconomic headwinds are present, the          │
# │  company's ability to innovate and maintain its technological lead is expected to outweigh these challenges in  │
# │  the near to medium term. Therefore, our core recommendation for NVIDIA heading into 2025 is a **Buy**.         │
# │  Investors should, however, remain vigilant regarding competitive developments and geopolitical factors, which  │
# │  warrant ongoing monitoring.                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
